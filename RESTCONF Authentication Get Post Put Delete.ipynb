# %%
### RESTCONF INTERFACES GET POST PUT DELETE
### OPTIONS
###### GET Read
###### PATCH Update
###### PUT Create or Replace
###### POST Create or Operations (reload, default) ==> you can only POST once (on creation)!
###### DELETE Deletes the targeted resource
###### HEAD Header metadata (no response body)
###
import datetime
print ("Current date and time: ")
print(datetime.datetime.now())

print('Starting RESTCONF INTERFACES GET POST PUT DELETE')

print('-------1-------')
print('Importing libraries json and requests, disabling SSL verification warning')
import json
import requests

# Disable SSL Verification Warning because of Private SSL Certificate
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
#requests.packages.urllib3.disable_warnings()
#dir(requests)
#dir(json)

# %%
### RESTCONF IETF-INTERFACES
import datetime
print ("Current date and time: ")
print(datetime.datetime.now())

# Disable SSL Verification Warning because of Private SSL Certificate
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

print('Creating request and necessary variables')
print('-------1-------')
router_ip = "192.168.56.107" ### check ip address of local virtual router
print("Router IP: " + router_ip)

print('-------2-------')
api_url = "https://{0}/restconf/data/ietf-interfaces:interfaces".format(router_ip)
print("restconf url: " + api_url)

print('-------3-------')
# A mistake in the headers generates an HHTP ERROR 406 Not Acceptable
headers = {
    "Accept": "application/yang-data+json",
    "Content-Type": "application/yang-data+json"
}
print(type(headers))
print(headers)

print('-------4-------')
#A wrong password will generate HTTP ERROR 401 Unauthorized
basicauth =('cisco', 'cisco123!')
print(type(basicauth))
print(basicauth)
print("=> request executed in next cell")

# %%
import requests
import json
import datetime
print ("Current date and time: ")
print(datetime.datetime.now())

# Disable SSL Verification Warning because of Private SSL Certificate
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

print('-------1-------')
print('=> Sending GET request for information interfaces')
# Remark: Dynamic DHCP Address not shown
# alternative A: 
#resp = requests.get(api_url, auth=basicauth, headers=headers, verify=False)
# alternative B: 
resp = requests.request('GET', api_url, auth=basicauth, headers=headers, verify=False)
print("requests.session():" )
print(requests.session())
print("requests.codes.ok: ")
print(requests.codes.ok)
print("resp.headers: ")
print(resp.headers)

print('-------2-------')
print("type(resp): ")
print(type(resp))
print("resp: ")
print(resp)

print('-------3-------')
response_json = resp.json()
print("type(response_json): ")
print(type(response_json))
print("response_json: ")      
print(response_json)

print('-------4-------')
print('=> Pretty print --- Dynamic DHCP Address not shown')
print("json.dumps(response_json,  indent=4) :")      
print(json.dumps(response_json,  indent=4))

# %%
### RESTCONF IETF-INTERFACES
import requests
import json
import datetime
print ("Current date and time: ")
print(datetime.datetime.now())

# Disable SSL Verification Warning because of Private SSL Certificate
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

print('Creating PUT request for additional interface')
print('-------1-------')
### check ip address of local virtual router
router_ip = "192.168.56.107"
new_interface ='Loopback10111'
new_ip = '10.1.1.1'
print("Router IP: " +router_ip)

print('-------2-------')
api_url = "https://{0}/restconf/data/ietf-interfaces:interfaces/interface={1}".format(router_ip,new_interface)
print("Restconf URL: " +api_url)

print('-------3-------')
# A mistake in the headers generates an HTTP ERROR 406 Not Acceptable or HTTP 400 Malformed message
headers = {
    "Accept": "application/yang-data+json",
    "Content-type": "application/yang-data+json"
}
print(type(headers))
print(headers)

print('-------4-------')
basicauth =('cisco', 'cisco123!')
print(type(basicauth))
print(basicauth)

print('-------5-------')
yang_config = {
  "ietf-interfaces:interface": {
    "name": new_interface,
    "description": "New RESTCONF loopback",
    "type": "iana-if-type:softwareLoopback",
    "enabled": True,
    "ietf-ip:ipv4": {
      "address": [
        {
          "ip": new_ip,
          "netmask": "255.255.255.0"
        }
      ]
    },
    "ietf-ip:ipv6": {}
  }
}
print(type(yang_config))
print(yang_config)

print('-------6-------')
print(json.dumps(yang_config, indent=4))
print('-------7-------')
print("=> request executed in next cell")

# %%
import requests
import json
import datetime
print ("Current date and time: ")
print(datetime.datetime.now())

# Disable SSL Verification Warning because of Private SSL Certificate
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

print('Sending POST or PUT request to configure interface')
resp = requests.request('PUT', api_url, auth=basicauth, headers=headers, json=yang_config, verify=False)
print(resp.status_code)

print('-------1-------')
print(api_url)
print(resp.status_code)

print('-------2-------')
print(type(resp))
print(resp)
# SHOULD BE: 201 Created

# %%
### RESTCONF: Delete interface
import requests
import json
import datetime
print ("Current date and time: ")
print(datetime.datetime.now())

# Disable SSL Verification Warning because of Private SSL Certificate
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

print('Sending DELETE request to remove interface')
del_interface = "Loopback" + input("What loopback number to delete? ")
print(del_interface)
### https://192.168.56.107/restconf/data/ietf-interfaces:interfaces/interface=Loopback10111
api_url = "https://{0}/restconf/data/ietf-interfaces:interfaces/interface={1}".format(router_ip, del_interface)

print('-------1-------')
yang_config = {
  "ietf-interfaces:interface": {
    "name": new_interface,
    "description": "",
    "type": "iana-if-type:softwareLoopback",
    "enabled": False,
    "ietf-ip:ipv4": {
      "address": [
        {
          "ip": "",
          "netmask": ""
        }
      ]
    },
    "ietf-ip:ipv6": {}
  }
}
resp = requests.request('DELETE', api_url, auth=basicauth, headers=headers, json=yang_config, verify=False)
print(resp.status_code)

print('-------2-------')
print(api_url)
print(resp.status_code)

print('-------3-------')
print(type(resp))
print(resp.text)
# SHOULD BE: 204 No Content

# %%
### RESTCONF CISCO IOS-XE-INTERFACES
# https://github.com/jeremycohoe/restconf-catalyst-3850/blob/master/restconf_c3850.py
# Jeremy Cohoe jeremycohoe
# https://www.ciscolive.com/c/dam/r/ciscolive/us/docs/2019/pdf/5eU6DfQV/LTRCRT-2700-LG.pdf
# Tony Roman, LTRCRT-2700
import requests
from requests.auth import HTTPBasicAuth
import json
import datetime
print ("Current date and time: ")
print(datetime.datetime.now())

# Disable SSL Verification Warning because of Private SSL Certificate
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

auth = HTTPBasicAuth('cisco', 'cisco123!')
#print(dir(auth))
print(auth.username)
print(auth.password)
print(auth.__dict__)

media_type = 'application/yang-data+json'
headers = { 'Accept': media_type, 'Content-Type': media_type }
payload  = {}

url = "https://192.168.56.107/restconf/data/Cisco-IOS-XE-interfaces-oper:interfaces/interface?fields=name;speed;phys-address;admin-status;statistics/in-octets;statistics/out-octets"

response = requests.request("GET", url, auth=auth, headers=headers, data = payload, verify=False)

print("API: ", url)
print(response.status_code)

if response.status_code in [200, 202, 204]:
    print("Successful")
else: 
    print("Error in API")
    
#print(response.text.encode('utf8'))
print(response.json())

# %%
### RESTCONF CISCO IOS-XE-INTERFACES
### ROMAN 1
# https://www.ciscolive.com/c/dam/r/ciscolive/us/docs/2019/pdf/5eU6DfQV/LTRCRT-2700-LG.pdf
# Tony Roman, LTRCRT-2700
import requests
from requests.auth import HTTPBasicAuth
import json
import datetime
print ("Current date and time: ")
print(datetime.datetime.now())

# Disable SSL Verification Warning because of Private SSL Certificate
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

auth = HTTPBasicAuth('cisco', 'cisco123!')
media_type = 'application/yang-data+json'
headers = { 'Accept': media_type, 'Content-Type': media_type }
url = "https://192.168.56.107/restconf/data/Cisco-IOS-XE-native:native/interface"

# this also works if you remove "name" key from JSON payload:
# https://csr1kv/restconf/data/Cisco-IOS-XE-native:native/interface/Loopback/100
payload = {
    "Cisco-IOS-XE-native:Loopback": {
        "name": "121",
        "ip": {
            "address": {
                "primary": {
                    "address": "10.1.2.1",
                    "mask": "255.255.255.255" }
            }}}}

print("Performing Request")
response = requests.post(url, headers=headers, auth=auth, data=payload, verify=False)
print(response.status_code)

if response.status_code >= 400:
 print("Remember, you can only POST once (on creation)!")
url = "https://192.168.56.107/restconf/data/Cisco-IOS-XE-native:native/interface/Loopback=121"
response = requests.get(url, headers=headers, auth=auth, verify=False)
print(response.text)

# %%
### ROMAN 2
# https://www.ciscolive.com/c/dam/r/ciscolive/us/docs/2019/pdf/5eU6DfQV/LTRCRT-2700-LG.pdf
# Tony Roman, LTRCRT-2700
import requests
import json
from requests.auth import HTTPBasicAuth
import datetime
print ("Current date and time: ")
print(datetime.datetime.now())

# Disable SSL Verification Warning because of Private SSL Certificate
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

auth = HTTPBasicAuth('cisco', 'cisco123!')
media_type = 'application/yang-data+json'
headers = { 'Accept': media_type, 'Content-Type': media_type }

url1 = "https://192.168.56.107/restconf/data/Cisco-IOS-XE-native:native"
url2 = "https://192.168.56.107/restconf/data/Cisco-IOS-XE-native:native?depth=1"
url3 = "https://192.168.56.107/restconf/data/Cisco-IOS-XE-native:native/interface"
url4 = "https://192.168.56.107/restconf/data/Cisco-IOS-XE-native:native/interface/GigabitEthernet=1"
url5 = "https://192.168.56.107/restconf/data/Cisco-IOS-XE-native:native/interface/GigabitEthernet=1/ip"
url6 = "https://192.168.56.107/restconf/data/Cisco-IOS-XE-native:native/interface/GigabitEthernet=1/ip/address"

url = url3

response = requests.get(url, headers=headers, auth=auth, data=payload, verify=False)
print(response.status_code)
response_dict = response.json()
print(type(response_dict))
print(json.dumps(response_dict, indent=2))
