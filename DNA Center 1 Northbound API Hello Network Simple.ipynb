# %%
#### DNA Center => Manage Enterprise Networks and Devices
#STEP 1 => DEFINE HARD CODED VARIABLES TO BE USED IN THE SCRIPT
####### TASKS
# TASK1: display the keys of the json repsonse
# TASK2: filter => hostname, type, ip address
# TASK3: display filtered data in a table format
import requests
import datetime
import json
requests.packages.urllib3.disable_warnings()
print ("Current date and time: ")
print(datetime.datetime.now())
print('Starting DNA Center Hello World - Simple')
print('Creating Hard Coded Variables')

# HARD CODED VARIABLES
DNAC_scheme = 'https://'
DNAC_authority='sandboxdnac.cisco.com'
DNAC_port=':443'
DNAC_path_token='/dna/system/api/v1/auth/token'
DNAC_path='/dna/intent/api/v1/network-device'
DNAC_user = 'devnetuser'
DNAC_psw = 'Cisco123!'
#DNAC_user = input("Username? ")
#DNAC_psw = input("Password? ")
# Out:
# Current date and time:
# 2021-03-11 20:33:02.095300
# Starting DNA Center Hello World - Simple
# Creating Hard Coded Variables

# %%
#STEP 2 => REQUEST TOKEN BASED ON USERNAME AND PASSWORD
print ("Current date and time: ")
print(datetime.datetime.now())
print('Post First Request - Token')
# FIRST REQUEST
token_req_url = DNAC_scheme+DNAC_authority+DNAC_path_token
print(token_req_url)
auth = (DNAC_user, DNAC_psw)
print(type(auth))
#req = requests.request('POST', token_req_url, auth=auth, verify=False)
req = requests.post(token_req_url, auth=(DNAC_user, DNAC_psw), verify=False)
#req = requests.request('POST', token_req_url, auth=(DNAC_user, DNAC_psw), verify=False)
req = requests.post(token_req_url, auth=(DNAC_user, DNAC_psw), verify=False)
print(req)
print("API Return Code: " + str(req.status_code))  
print('Request URI: ' + token_req_url)
print("Username: " + DNAC_user)
resp = req.text
print(resp)
token = req.json()['Token']
print("Received Token:")
print(token)
print("Length Token:")
print(len(token))
# Out:
# Current date and time:
# 2021-03-11 20:33:03.867186
# Post First Request - Token
# https://sandboxdnac.cisco.com/dna/system/api/v1/auth/token
# <class 'tuple'>
# <Response [200]>
# API Return Code: 200
# Request URI: https://sandboxdnac.cisco.com/dna/system/api/v1/auth/token
# Username: devnetuser
# {"Token":"eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..bHrRYAe-QDW54A6BBj0ieYumLgbiy9-oEU1GNbwbYPMb_j0gKnJTXZtdjZvs6gQpHE6O0UxDTCFHaTxh8MQvSwckh8P7PPrllVHYsaP_-AKOBTD2c03MyyVmqex2Y4cHEco-1GdOP0vmSWJIXbQzUPg4nLo-44Y1INZ_fe4AkwitIQJ7RkKGviHq8zMX5Pqt3wBlSR5Jf8gpMO5HEFdbSegr_CAxNLs31kukCp5qmiMsEWxBUwwPQVopxBEhw5UfJ7Pmw9hjBnJ7PzxgnbtPG5pS0XsAAbaWLQnkZK4lgXBme9nAcjLgFyONFWeYMVK9zAGsaszaqUG8-AcRoX3PJw"}
# Received Token:
# eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..bHrRYAe-QDW54A6BBj0ieYumLgbiy9-oEU1GNbwbYPMb_j0gKnJTXZtdjZvs6gQpHE6O0UxDTCFHaTxh8MQvSwckh8P7PPrllVHYsaP_-AKOBTD2c03MyyVmqex2Y4cHEco-1GdOP0vmSWJIXbQzUPg4nLo-44Y1INZ_fe4AkwitIQJ7RkKGviHq8zMX5Pqt3wBlSR5Jf8gpMO5HEFdbSegr_CAxNLs31kukCp5qmiMsEWxBUwwPQVopxBEhw5UfJ7Pmw9hjBnJ7PzxgnbtPG5pS0XsAAbaWLQnkZK4lgXBme9nAcjLgFyONFWeYMVK9zAGsaszaqUG8-AcRoX3PJw
# Length Token:
# 722

# %%
#STEP 3 => REQUEST API SERVICE (USING X-AUTH-TOKEN FROM STEP 2)
import datetime
print ("Current date and time: ")
print(datetime.datetime.now())
print('Second Request - Network Devices')
# SECOND REQUEST
req_url = DNAC_scheme+DNAC_authority+DNAC_port+DNAC_path
print(req_url)
headers = {'X-auth-token': token}
resp_devices = requests.request('GET', req_url, headers=headers, verify=False)
print(resp_devices)
resp_devices_json = resp_devices.json()
print("Response (json):")
print(json.dumps(resp_devices_json, indent=4))
#### keys
#### print(resp_devices_json.keys())
# Out:
# Current date and time:
# 2021-03-11 20:34:16.928286
# Second Request - Network Devices
# https://sandboxdnac.cisco.com:443/dna/intent/api/v1/network-device
# <Response [200]>
# Response (json):
# {
#     "response": [
#         {
#             "hostname": "asr1001-x.abc.inc",
#             "apEthernetMacAddress": null,
#             "apManagerInterfaceIp": "",
#             "associatedWlcIp": "",
#             "bootDateTime": "2021-02-16 21:06:54",
#             "macAddress": "00:c8:8b:80:bb:00",
#             "roleSource": "AUTO",
#             "collectionInterval": "Global Default",
#             "upTime": "22 days, 20:30:24.83",
#             "deviceSupportLevel": "Supported",
#             "softwareType": "IOS-XE",
#             "softwareVersion": "16.3.2",
#             "collectionStatus": "Managed",
#             "errorCode": null,
#             "errorDescription": null,
#             "family": "Routers",
#             "interfaceCount": "0",
#             "lastUpdated": "2021-03-11 17:36:54",
#             "lineCardCount": "0",
#             "lineCardId": "",
#             "locationName": null,
#             "managedAtleastOnce": true,
#             "managementIpAddress": "10.10.22.253",
#             "memorySize": "NA",
#             "platformId": "ASR1001-X",
#             "reachabilityFailureReason": "",
#             "reachabilityStatus": "Reachable",
#             "series": "Cisco ASR 1000 Series Aggregation Services Routers",
#             "snmpContact": "",
#             "snmpLocation": "",
#             "tagCount": "0",
#             "tunnelUdpPort": null,
#             "uptimeSeconds": 1981643,
#             "waasDeviceMode": null,
#             "lastUpdateTime": 1615484214450,
#             "description": "Cisco IOS Software [Denali], ASR1000 Software (X86_64_LINUX_IOSD-UNIVERSALK9-M), Version 16.3.2, RELEASE SOFTWARE (fc4) Technical Support: http://www.cisco.com/techsupport Copyright (c) 1986-2016 by Cisco Systems, Inc. Compiled Tue 08-Nov-16 18:21 by m",
#             "inventoryStatusDetail": "<status><general code=\"SUCCESS\"/></status>",
#             "managementState": "Managed",
#             "serialNumber": "FXS1932Q1SE",
#             "type": "Cisco ASR 1001-X Router",
#             "location": null,
#             "role": "BORDER ROUTER",
#             "instanceTenantId": "602bebe514710a00c98fa402",
#             "instanceUuid": "6aad2ec7-d1d0-4605-bf32-f62266c5f53e",
#             "id": "6aad2ec7-d1d0-4605-bf32-f62266c5f53e"
#         },
#         {
#             "hostname": "cat_9k_1",
#             "apEthernetMacAddress": null,
#             "apManagerInterfaceIp": "",
#             "associatedWlcIp": "",
#             "bootDateTime": "2020-12-24 17:12:41",
#             "macAddress": "f8:7b:20:67:62:80",
#             "roleSource": "AUTO",
#             "collectionInterval": "Global Default",
#             "upTime": "77 days, 0:27:49.76",
#             "deviceSupportLevel": "Supported",
#             "softwareType": "IOS-XE",
#             "softwareVersion": "17.3.1",
#             "collectionStatus": "Managed",
#             "errorCode": null,
#             "errorDescription": null,
#             "family": "Switches and Hubs",
#             "interfaceCount": "0",
#             "lastUpdated": "2021-03-11 17:39:41",
#             "lineCardCount": "0",
#             "lineCardId": "",
#             "locationName": null,
#             "managedAtleastOnce": true,
#             "managementIpAddress": "10.10.22.66",
#             "memorySize": "NA",
#             "platformId": "C9300-24UX",
#             "reachabilityFailureReason": "",
#             "reachabilityStatus": "Reachable",
#             "series": "Cisco Catalyst 9300 Series Switches",
#             "snmpContact": "",
#             "snmpLocation": "",
#             "tagCount": "0",
#             "tunnelUdpPort": null,
#             "uptimeSeconds": 6661296,
#             "waasDeviceMode": null,
#             "lastUpdateTime": 1615484381433,
#             "description": "Cisco IOS Software [Amsterdam], Catalyst L3 Switch Software (CAT9K_IOSXE), Version 17.3.1, RELEASE SOFTWARE (fc5) Technical Support: http://www.cisco.com/techsupport Copyright (c) 1986-2020 by Cisco Systems, Inc. Compiled Fri 07-Aug-20 21:32 by mcpre",
#             "inventoryStatusDetail": "<status><general code=\"SUCCESS\"/></status>",
#             "managementState": "Managed",
#             "serialNumber": "FCW2136L0AK",
#             "type": "Cisco Catalyst 9300 Switch",
#             "location": null,
#             "role": "ACCESS",
#             "instanceTenantId": "602bebe514710a00c98fa402",
#             "instanceUuid": "183ed3e6-3472-405c-a1ce-26d07987a140",
#             "id": "183ed3e6-3472-405c-a1ce-26d07987a140"
#         },
#         {
#             "hostname": "cat_9k_2",
#             "apEthernetMacAddress": null,
#             "apManagerInterfaceIp": "",
#             "associatedWlcIp": "",
#             "bootDateTime": "2020-08-17 07:34:26",
#             "macAddress": "f8:7b:20:71:4d:80",
#             "roleSource": "AUTO",
#             "collectionInterval": "Global Default",
#             "upTime": "206 days, 10:02:04.90",
#             "deviceSupportLevel": "Supported",
#             "softwareType": "IOS-XE",
#             "softwareVersion": "16.6.4a",
#             "collectionStatus": "Managed",
#             "errorCode": null,
#             "errorDescription": null,
#             "family": "Switches and Hubs",
#             "interfaceCount": "0",
#             "lastUpdated": "2021-03-11 17:36:26",
#             "lineCardCount": "0",
#             "lineCardId": "",
#             "locationName": null,
#             "managedAtleastOnce": true,
#             "managementIpAddress": "10.10.22.70",
#             "memorySize": "NA",
#             "platformId": "C9300-24UX",
#             "reachabilityFailureReason": "",
#             "reachabilityStatus": "Reachable",
#             "series": "Cisco Catalyst 9300 Series Switches",
#             "snmpContact": "",
#             "snmpLocation": "",
#             "tagCount": "0",
#             "tunnelUdpPort": null,
#             "uptimeSeconds": 17841591,
#             "waasDeviceMode": null,
#             "lastUpdateTime": 1615484186011,
#             "description": "Cisco IOS Software [Everest], Catalyst L3 Switch Software (CAT9K_IOSXE), Version 16.6.4a, RELEASE SOFTWARE (fc3) Technical Support: http://www.cisco.com/techsupport Copyright (c) 1986-2018 by Cisco Systems, Inc. Compiled Fri 26-Oct-18 18:15 by mcpre",
#             "inventoryStatusDetail": "<status><general code=\"SUCCESS\"/></status>",
#             "managementState": "Managed",
#             "serialNumber": "FCW2140L039",
#             "type": "Cisco Catalyst 9300 Switch",
#             "location": null,
#             "role": "ACCESS",
#             "instanceTenantId": "602bebe514710a00c98fa402",
#             "instanceUuid": "bf5ac35b-f1bc-4e15-8512-2ae22f507608",
#             "id": "bf5ac35b-f1bc-4e15-8512-2ae22f507608"
#         },
#         {
#             "hostname": "cs3850.abc.inc",
#             "apEthernetMacAddress": null,
#             "apManagerInterfaceIp": "",
#             "associatedWlcIp": "",
#             "bootDateTime": "2021-02-16 21:08:29",
#             "macAddress": "cc:d8:c1:15:d2:80",
#             "roleSource": "AUTO",
#             "collectionInterval": "Global Default",
#             "upTime": "22 days, 20:48:32.26",
#             "deviceSupportLevel": "Supported",
#             "softwareType": "IOS-XE",
#             "softwareVersion": "16.9.5",
#             "collectionStatus": "Managed",
#             "errorCode": null,
#             "errorDescription": null,
#             "family": "Switches and Hubs",
#             "interfaceCount": "0",
#             "lastUpdated": "2021-03-11 17:56:29",
#             "lineCardCount": "0",
#             "lineCardId": "",
#             "locationName": null,
#             "managedAtleastOnce": true,
#             "managementIpAddress": "10.10.22.73",
#             "memorySize": "NA",
#             "platformId": "WS-C3850-48U-E",
#             "reachabilityFailureReason": "",
#             "reachabilityStatus": "Reachable",
#             "series": "Cisco Catalyst 3850 Series Ethernet Stackable Switch",
#             "snmpContact": "",
#             "snmpLocation": "",
#             "tagCount": "0",
#             "tunnelUdpPort": null,
#             "uptimeSeconds": 1981547,
#             "waasDeviceMode": null,
#             "lastUpdateTime": 1615485389957,
#             "description": "Cisco IOS Software [Fuji], Catalyst L3 Switch Software (CAT3K_CAA-UNIVERSALK9-M), Version 16.9.5, RELEASE SOFTWARE (fc1) Technical Support: http://www.cisco.com/techsupport Copyright (c) 1986-2020 by Cisco Systems, Inc. Compiled Thu 30-Jan-20 18:17 by",
#             "inventoryStatusDetail": "<status><general code=\"SUCCESS\"/></status>",
#             "managementState": "Managed",
#             "serialNumber": "FOC1833X0AR",
#             "type": "Cisco Catalyst38xx stack-able ethernet switch",
#             "location": null,
#             "role": "DISTRIBUTION",
#             "instanceTenantId": "602bebe514710a00c98fa402",
#             "instanceUuid": "5d6dd65b-eb43-4e28-bd31-e6b0730b2ac5",
#             "id": "5d6dd65b-eb43-4e28-bd31-e6b0730b2ac5"
#         }
#     ],
#     "version": "1.0"
# }

# %%
#STEP 4 => RETURNED DATA => FILTERING AND LOOPING
print ("Current date and time: ")
print(datetime.datetime.now())
print('Second Request - Providing simple output')
#OUTPUT USING A LOOP TO PROCESS LIST ITEMS
for device in resp_devices_json['response']:
    if device['type'] != None:
        print('Hostname: '+device['hostname']+' Type: '+device['type']+' IP: '+device['managementIpAddress'])
# Out:
# Current date and time:
# 2021-03-11 20:34:27.180717
# Second Request - Providing simple output
# Hostname: asr1001-x.abc.inc Type: Cisco ASR 1001-X Router IP: 10.10.22.253
# Hostname: cat_9k_1 Type: Cisco Catalyst 9300 Switch IP: 10.10.22.66
# Hostname: cat_9k_2 Type: Cisco Catalyst 9300 Switch IP: 10.10.22.70
# Hostname: cs3850.abc.inc Type: Cisco Catalyst38xx stack-able ethernet switch IP: 10.10.22.73

# %%
#STEP 5 => FILTERING JSON DATA 
print ("Current date and time: ")
print(datetime.datetime.now())
print('Second Request - Providing  output in JSON')
#CREATE EMPTY LIST
dev_list = []
for device in resp_devices_json['response']:
    if device['type'] != None:
        #CREATE EMPTY DICT
        dev_dict = {}
        dev_dict['hostname'] = device['hostname']
        dev_dict['type'] = device['type']
        #dev_dict['macAddress'] = device['macAddress']
        dev_dict['managementIpAddress'] = device['managementIpAddress']
        dev_dict['serialNumber'] = device['serialNumber']
        dev_dict['softwareType'] = device['softwareType']
        dev_dict['softwareVersion'] = device['softwareVersion']
        dev_dict['reachabilityStatus'] = device['reachabilityStatus']
        dev_list.append(dev_dict)
#print(dev_list)     
print(json.dumps(dev_list, indent=2))
# Out:
# Current date and time:
# 2021-03-11 16:23:00.742545
# Second Request - Providing  output in JSON
# [
#   {
#     "hostname": "asr1001-x.abc.inc",
#     "type": "Cisco ASR 1001-X Router",
#     "managementIpAddress": "10.10.22.253",
#     "serialNumber": "FXS1932Q1SE",
#     "softwareType": "IOS-XE",
#     "softwareVersion": "16.3.2",
#     "reachabilityStatus": "Reachable"
#   },
#   {
#     "hostname": "cat_9k_1",
#     "type": "Cisco Catalyst 9300 Switch",
#     "managementIpAddress": "10.10.22.66",
#     "serialNumber": "FCW2136L0AK",
#     "softwareType": "IOS-XE",
#     "softwareVersion": "17.3.1",
#     "reachabilityStatus": "Reachable"
#   },
#   {
#     "hostname": "cat_9k_2",
#     "type": "Cisco Catalyst 9300 Switch",
#     "managementIpAddress": "10.10.22.70",
#     "serialNumber": "FCW2140L039",
#     "softwareType": "IOS-XE",
#     "softwareVersion": "16.6.4a",
#     "reachabilityStatus": "Reachable"
#   },
#   {
#     "hostname": "cs3850.abc.inc",
#     "type": "Cisco Catalyst38xx stack-able ethernet switch",
#     "managementIpAddress": "10.10.22.73",
#     "serialNumber": "FOC1833X0AR",
#     "softwareType": "IOS-XE",
#     "softwareVersion": "16.9.5",
#     "reachabilityStatus": "Reachable"
#   }
# ]

# %%
### TO DO: add column titles
from tabulate import *
print(type(dev_list))
print(tabulate(dev_list))
# Out:
# <class 'list'>
# -----------------  ---------------------------------------------  ------------  -----------  ------  -------  ---------
# asr1001-x.abc.inc  Cisco ASR 1001-X Router                        10.10.22.253  FXS1932Q1SE  IOS-XE  16.3.2   Reachable
# cat_9k_1           Cisco Catalyst 9300 Switch                     10.10.22.66   FCW2136L0AK  IOS-XE  17.3.1   Reachable
# cat_9k_2           Cisco Catalyst 9300 Switch                     10.10.22.70   FCW2140L039  IOS-XE  16.6.4a  Reachable
# cs3850.abc.inc     Cisco Catalyst38xx stack-able ethernet switch  10.10.22.73   FOC1833X0AR  IOS-XE  16.9.5   Reachable
# -----------------  ---------------------------------------------  ------------  -----------  ------  -------  ---------

# %%
import yaml
#yaml_data = yaml.dump(dev_list)
#yaml_data = yaml.dump(resp_devices_json)
yaml_data = yaml.dump(dev_list)
print(yaml_data)
# Out:
# - hostname: asr1001-x.abc.inc
#   managementIpAddress: 10.10.22.253
#   reachabilityStatus: Reachable
#   serialNumber: FXS1932Q1SE
#   softwareType: IOS-XE
#   softwareVersion: 16.3.2
#   type: Cisco ASR 1001-X Router
# - hostname: cat_9k_1
#   managementIpAddress: 10.10.22.66
#   reachabilityStatus: Reachable
#   serialNumber: FCW2136L0AK
#   softwareType: IOS-XE
#   softwareVersion: 17.3.1
#   type: Cisco Catalyst 9300 Switch
# - hostname: cat_9k_2
#   managementIpAddress: 10.10.22.70
#   reachabilityStatus: Reachable
#   serialNumber: FCW2140L039
#   softwareType: IOS-XE
#   softwareVersion: 16.6.4a
#   type: Cisco Catalyst 9300 Switch
# - hostname: cs3850.abc.inc
#   managementIpAddress: 10.10.22.73
#   reachabilityStatus: Reachable
#   serialNumber: FOC1833X0AR
#   softwareType: IOS-XE
#   softwareVersion: 16.9.5
#   type: Cisco Catalyst38xx stack-able ethernet switch
