# %%
### DevNet Associate Course Lab 4.9.2 MapQuest 
import urllib.parse 
import requests 
import json
print('MapQuest API Lab -- Get Route')
print('Hands-on lab using Get Route which is a part of the MapQuest API ecosystem')
print('Steps used below are different from the steps in the basic lab')
print('STEP 1: Import necessary libraries: urllib.parse and requests')
print('STEP 2: Define URL for the API to be called as well as the key to be given access')
main_api = "https://www.mapquestapi.com/directions/v2/route?" 
key = "th0o4YURLPy443wAxKekVk1OzaNOkJqm" 
print('STEP 3: Key: ' + key)
# Out:
# MapQuest API Lab -- Get Route
# Hands-on lab using Get Route which is a part of the MapQuest API ecosystem
# Steps used below are different from the steps in the basic lab
# STEP 1: Import necessary libraries: urllib.parse and requests
# STEP 2: Define URL for the API to be called as well as the key to be given access
# STEP 3: Key: th0o4YURLPy443wAxKekVk1OzaNOkJqm

# %%
print('STEP 4: Request ORIGIN and DESTINATION')
orig = input("Starting Location: ")     
if orig != "quit" or orig != "q" or orig != "":
    dest = input("Destination: ")     
if dest != "quit" or dest != "q" or dest != "":
    print('STEP 5: Here are the origin and destination requested: ')
    print('START ==> ' + orig)
    print('FINISH ==> ' + dest)
else:
    print('No request for ORIGIN and DESTINATION')
# Out:
# STEP 4: Request ORIGIN and DESTINATION
# Starting Location: Helsinki
# Destination: Joensuu
# STEP 5: Here are the origin and destination requested:
# START ==> Helsinki
# FINISH ==> Joensuu

# %%
print('STEP 6: Combine the four variables main_api, orig, dest, and key to format the requested URL')
print('Use the urlencode method to properly format the address value') 
url = main_api + urllib.parse.urlencode({"key": key, "from":orig, "to":dest}) 
print('STEP 6b: New Request URL')
print('URL ==> ' + url)
print('STEP 6c: Sending API request')
resp = requests.get(url)
print(resp.status_code)
json_data = resp.json() 
print('STEP 6d: Printing JSON status')
json_status = json_data["info"]["statuscode"]
if json_status == 0:
    print('Status: 0 (OK)')
else:
    print('Status: not OK')
print('STEP 6e: Printing raw JSON data')
print('HERE ARE THE JSON DATA ...')
print('==============================================================')
print(json_data) 
print('==============================================================')
# Out:
# STEP 6: Combine the four variables main_api, orig, dest, and key to format the requested URL
# Use the urlencode method to properly format the address value
# STEP 6b: New Request URL
# URL ==> https://www.mapquestapi.com/directions/v2/route?key=th0o4YURLPy443wAxKekVk1OzaNOkJqm&from=Helsinki&to=Joensuu
# STEP 6c: Sending API request
# 200
# STEP 6d: Printing JSON status
# Status: 0 (OK)
# STEP 6e: Printing raw JSON data
# HERE ARE THE JSON DATA ...
# ==============================================================
# {'route': {'hasTollRoad': False, 'hasBridge': False, 'boundingBox': {'lr': {'lng': 29.766739, 'lat': 60.166603}, 'ul': {'lng': 24.92811, 'lat': 62.634487}}, 'distance': 271.63, 'hasTimedRestriction': False, 'hasTunnel': False, 'hasHighway': True, 'computedWaypoints': [], 'routeError': {'errorCode': -400, 'message': ''}, 'formattedTime': '04:44:31', 'sessionId': '604a3feb-03e4-4ee4-02b4-3580-126314f82f4f', 'hasAccessRestriction': False, 'realTime': -1, 'hasSeasonalClosure': False, 'hasCountryCross': False, 'fuelUsed': 12.48, 'legs': [{'hasTollRoad': False, 'hasBridge': False, 'destNarrative': 'Proceed to GIOENSOU, ITÄ-SUOMI.', 'distance': 271.63, 'hasTimedRestriction': False, 'hasTunnel': False, 'hasHighway': True, 'index': 0, 'formattedTime': '04:44:31', 'origIndex': 1, 'hasAccessRestriction': False, 'hasSeasonalClosure': False, 'hasCountryCross': False, 'roadGradeStrategy': [[]], 'destIndex': 10, 'time': 17071, 'hasUnpaved': False, 'origNarrative': 'Go northwest on Mannerheimintie/E12.', 'maneuvers': [{'distance': 0.005, 'streets': ['Bulevardi'], 'narrative': 'Start out going northeast on Bulevardi toward Erottajankatu.', 'turnType': 0, 'startPoint': {'lng': 24.943516, 'lat': 60.166603}, 'index': 0, 'formattedTime': '00:00:01', 'directionName': 'Northeast', 'maneuverNotes': [], 'linkIds': [], 'signs': [], 'mapUrl': 'http://www.mapquestapi.com/staticmap/v5/map?key=th0o4YURLPy443wAxKekVk1OzaNOkJqm&size=225,160&locations=60.166603088378906,24.94351577758789|marker-1||60.166648864746094,24.943635940551758|marker-2||&center=60.1666259765625,24.943575859069824&defaultMarker=none&zoom=15&rand=-2074703914&session=604a3feb-03e4-4ee4-02b4-3580-126314f82f4f', 'transportMode': 'AUTO', 'attributes': 0, 'time': 1, 'iconUrl': 'http://content.mqcdn.com/mqsite/turnsigns/icon-dirs-start_sm.gif', 'direction': 3}, {'distance': 1.119, 'streets': ['Mannerheimintie', 'E12'], 'narrative': 'Turn left onto Mannerheimintie/E12.', 'turnType': 6, 'startPoint': {'lng': 24.943636, 'lat': 60.166649}, 'index': 1, 'formattedTime': '00:03:07', 'directionName': 'Northwest', 'maneuverNotes': [], 'linkIds': [], 'signs': [], 'mapUrl': 'http://www.mapquestapi.com/staticmap/v5/map?key=th0o4YURLPy443wAxKekVk1OzaNOkJqm&size=225,160&locations=60.166648864746094,24.943635940551758|marker-2||60.18061447143555,24.928110122680664|marker-3||&center=60.17363166809082,24.93587303161621&defaultMarker=none&zoom=9&rand=-2074703914&session=604a3feb-03e4-4ee4-02b4-3580-126314f82f4f', 'transportMode': 'AUTO', 'attributes': 0, 'time': 187, 'iconUrl': 'http://content.mqcdn.com/mqsite/turnsigns/rs_left_sm.gif', 'direction': 2}, {'distance': 0.639, 'streets': ['Helsinginkatu'], 'narrative': 'Turn right onto Helsinginkatu.', 'turnType': 2, 'startPoint': {'lng': 24.92811, 'lat': 60.180614}, 'index': 2, 'formattedTime': '00:01:38', 'directionName': 'East', 'maneuverNotes': [], 'linkIds': [], 'signs': [], 'mapUrl': 'http://www.mapquestapi.com/staticmap/v5/map?key=th0o4YURLPy443wAxKekVk1OzaNOkJqm&size=225,160&locations=60.18061447143555,24.928110122680664|marker-3||60.18583679199219,24.940277099609375|marker-4||&center=60.18322563171387,24.93419361114502&defaultMarker=none&zoom=11&rand=-2074703914&session=604a3feb-03e4-4ee4-02b4-3580-126314f82f4f', 'transportMode': 'AUTO', 'attributes': 0, 'time': 98, 'iconUrl': 'http://content.mqcdn.com/mqsite/turnsigns/rs_right_sm.gif', 'direction': 8}, {'distance': 1.103, 'streets': ['Sturenkatu'], 'narrative': 'Turn slight left onto Sturenkatu.', 'turnType': 7, 'startPoint': {'lng': 24.940277, 'lat': 60.185837}, 'index': 3, 'formattedTime': '00:03:41', 'directionName': 'Northeast', 'maneuverNotes': [], 'linkIds': [], 'signs': [], 'mapUrl': 'http://www.mapquestapi.com/staticmap/v5/map?key=th0o4YURLPy443wAxKekVk1OzaNOkJqm&size=225,160&locations=60.18583679199219,24.940277099609375|marker-4||60.197288513183594,24.962242126464844|marker-5||&center=60.19156265258789,24.95125961303711&defaultMarker=none&zoom=9&rand=-2074703914&session=604a3feb-03e4-4ee4-02b4- ...
# ==============================================================

# %%
print('STEP 6b: Pretty Output of previous step')
print(json.dumps(json_data, indent=8))
# Out:
# STEP 6b: Pretty Output of previous step
# {
#         "route": {
#                 "hasTollRoad": false,
#                 "hasBridge": false,
#                 "boundingBox": {
#                         "lr": {
#                                 "lng": 29.766739,
#                                 "lat": 60.166603
#                         },
#                         "ul": {
#                                 "lng": 24.92811,
#                                 "lat": 62.634487
#                         }
#                 },
#                 "distance": 271.63,
#                 "hasTimedRestriction": false,
#                 "hasTunnel": false,
#                 "hasHighway": true,
#                 "computedWaypoints": [],
#                 "routeError": {
#                         "errorCode": -400,
#                         "message": ""
#                 },
#                 "formattedTime": "04:44:31",
#                 "sessionId": "604a3feb-03e4-4ee4-02b4-3580-126314f82f4f",
#                 "hasAccessRestriction": false,
#                 "realTime": -1,
#                 "hasSeasonalClosure": false,
#                 "hasCountryCross": false,
#                 "fuelUsed": 12.48,
#                 "legs": [
#                         {
#                                 "hasTollRoad": false,
#                                 "hasBridge": false,
#                                 "destNarrative": "Proceed to GIOENSOU, IT\u00c4-SUOMI.",
#                                 "distance": 271.63,
#                                 "hasTimedRestriction": false,
#                                 "hasTunnel": false,
#                                 "hasHighway": true,
#                                 "index": 0,
#                                 "formattedTime": "04:44:31",
#                                 "origIndex": 1,
#                                 "hasAccessRestriction": false,
#                                 "hasSeasonalClosure": false,
#                                 "hasCountryCross": false,
#                                 "roadGradeStrategy": [
#                                         []
#                                 ],
#                                 "destIndex": 10,
#                                 "time": 17071,
#                                 "hasUnpaved": false,
#                                 "origNarrative": "Go northwest on Mannerheimintie/E12.",
#                                 "maneuvers": [
#                                         {
#                                                 "distance": 0.005,
#                                                 "streets": [
#                                                         "Bulevardi"
#                                                 ],
#                                                 "narrative": "Start out going northeast on Bulevardi toward Erottajankatu.",
#                                                 "turnType": 0,
#                                                 "startPoint": {
#                                                         "lng": 24.943516,
#                                                         "lat": 60.166603
#                                                 },
#                                                 "index": 0,
#                                                 "formattedTime": "00:00:01",
#                                                 "directionName": "Northeast",
#                                                 "maneuverNotes": [],
#                                                 "linkIds": [],
#                                                 "signs": [],
#                                                 "mapUrl": "http://www.mapquestapi.com/staticmap/v5/map?key=th0o4YURLPy443wAxKekVk1OzaNOkJqm&size=225,160&locations=60.166603088378906,24.94351577758789|marker-1||60.166648864746094,24.943635940551758|marker-2||&center=60.1666259765625,24.943575859069824&defaultMarker=none&zoom=15&rand=-2074703914&session=604a3feb-03e4-4ee4-02b4-3580-126314f82f4f",
#                                                 "transportMode": "AUTO",
#                                                 "attributes": 0,
#                                                 "time": 1,
#                                                 "iconUrl": "http://content.mqcdn.com/mqsite/turnsigns/icon-dirs-start_sm.gif",
#                                                 "direction": 3
#                                         },
#                                         {
#                                                 "distance": 1.119,
#                                                 "streets": [
#                                                         "Mannerheimintie",
#                                                         "E12"
#                                                 ],
#                                                 "narrative": "Turn left onto Mannerheimintie/E12.",
#                                                 "turnType": 6,
#                                                 "startPoint": {
#                                                         "lng": 24.943636,
#                                                         "lat": 60.166649
#                                                 },
#                                                 "index": 1,
#                                                 "formattedTime": "00:03:07",
#                                                 "directionName": "Northwest",
#                                                 "maneuverNotes": [],
#                                                 "linkIds": [],
#                                                 "signs": [],
#                                                 "mapUrl": "http://www.mapquestapi.com/staticmap/v5/map?key=th0o4YURLPy443wAxKekVk1OzaNOkJqm&size=225,160&locations=60.166648864746094,24.943635940551758|marker-2||60.18061447143555,24.928110122680664|marker-3||&center=60.17363166809082,24.93587303161621&defaultMarker=none&zoom=9&rand=-2074703914&session=604a3feb-03e4-4ee4-02b4-3580-126314f82f4f",
#                                                 "transportMode": "AUTO",
#                                                 "attributes": 0,
#                                                 "time": 187,
#                                                 "iconUrl": "http://content.mqcdn.com/mqsite/turnsigns/rs_left_sm.gif",
#                                                 "direction": 2
#                                         },
#                                         {
#                                                 "distance": 0.639,
#                                                 "streets": [
#                                                         "Helsinginkatu"
#                                                 ],
#                                                 "narrative": "Turn right onto Helsinginkatu.",
#                                                 "turnType": 2,
#                                                 "startPoint": {
#                                                         "lng": 24.92811,
#                                                         "lat": 60.180614
#                                                 },
#                                                 "index": 2,
#                                                 "formattedTime": "00:01:38",
#                                                 "directionName": "East",
#                                                 "maneuverNotes": [],
#                                                 "linkIds": [],
#                                                 "signs": [],
#                                                 "mapUrl": "http://www.mapquestapi.com/staticmap/v5/map?key=th0o4YURLPy443wAxKekVk1OzaNOkJqm&size=225,160&locations=60.18061447143555,24.928110122680664|marker-3||60.18583679199219,24.940277099609375|marker-4||&center=60.18322563171387,24.93419361114502&defaultMarker=none&zoom=11&rand=-2074703914&session=604a3feb-03e4-4ee4-02b4-3580-126314f82f4f",
#                                                 "transportMode": "AUTO",
#                                                 "attributes": 0,
#                                                 "time": 98,
#                                                 "iconUrl": "http://content.mqcdn.com/mqsite/turnsigns/rs_right_sm.gif",
#                                                 "direction": 8
#                                         },
#                                         {
#                                                 "distance": 1.103,
#                                                 "streets": [
#                                                         "Sturenkatu"
#                                                 ],
#                                                 "narrative": "Turn slight left onto Sturenkatu.",
#                                                 "turnType": 7,
#                                                 "startPoint": {
#                                                         "lng": 24.940277,
#                                                         "lat": 60.185837
#                                                 },
#                                                 "index": 3,
#                                                 "formattedTime": "00:03:41",
#                                                 "directionName": "Northeast",
#                                                 "maneuverNotes": [],
#                                                 "linkIds": [],
#                                                 "signs": [],
#                                                 "mapUrl": "http://www.mapquestapi.com/staticmap/v5/map?key=th0o4YURLPy443wAxKekVk1OzaNOkJqm&size=225,160&locations=60.18583679199219,24.940277099609375|marker-4||60.197288513183594,24.962242126464844|marker-5||&center=60.19156265258789,24.95125961303711&defaultMarker=none&zoom=9&rand=-2074703914&session=604a3feb-03e4-4ee4-02b4-3580-126314f82f4f",
#                                                 "transportMode": "AUTO",
#                                                 "attributes": 0,
#                                                 "time": 221,
#                                                 "iconUrl": "http://content.mqcdn.com/mqsite/turnsigns/rs_slight_left_sm.gif",
#                                                 "direction": 3
#                                         },
#                                         {
#                                                 "distance": 0.424,
#                                                 "streets": [
#                                                         "H\u00e4meentie"
#                                                 ],
#                                                 "narrative": "Turn slight left onto H\u00e4meentie.",
#                                                 "turnType": 7,
#                                                 "startPoint": {
#                                                         "lng": 24.962242,
#                                                         "lat": 60.197289
#                                                 },
#                                                 "index": 4,
#                                                 "formattedTime": "00:00:58",
#                                                 "directionName": "North",
#                                                 "maneuverNotes": [],
#                                                 "linkIds": [],
#                                                 "signs": [],
#                                                 "mapUrl": "http://www.mapquestapi.com/staticmap/v5/map?key=th0o4YURLPy443wAxKekVk1OzaNOkJqm&size=225,160&locations=60.197288513183594,24.962242126464844|marker-5||60.2030029296875,24.965200424194336|marker-6||&center=60.20014572143555,24.96372127532959&defaultMarker=none&zoom=10&rand=-2074703914&session=604a3feb-03e4-4ee4-02b4-3580-126314f82f4f",
#                                                 "transportMode": "AUTO",
#                                                 "attributes": 0,
#                                                 "time": 58,
#                                                 "iconUrl": "http://content.mqcdn.com/mqsite/turnsigns/rs_slight_left_sm.gif",
#                                                 "direction": 1
#                                         },
#                                         {
#                                                 "distance": 87.589,
#                                                 "streets": [
#                                                         "E75"
#                                                 ],
#                                                 "narrative": "Stay straight to go onto Kustaa Vaasan tie/E75. Continue to follow E75.",
#                                                 "turnType": 0,
#                                                 "startPoint": {
#                                                         "lng": 24.9652,
#                                                         "lat": 60.203003
#                                                 },
#                                                 "index": 5,
#                                                 "formattedTime": "01:14:32",
#                                                 "directionName": "Northeast",
#                                                 "maneuverNotes": [],
#                                                 "linkIds": [],
#                                                 "signs": [],
#                                                 "mapUrl": "http://www.mapquestapi.com/staticmap/v5/map?key=th0o4YURLPy443wAxKekVk1OzaNOkJqm&size=225,160&locations=60.2030029296875,24.965200424194336|marker-6||61.28394317626953,26.070959091186523|marker-7||&center=60.743473052978516,25.51807975769043&defaultMarker=none&zoom=3&rand=-2074703914&session=604a3feb-03e4-4ee4-02b4-3580-126314f82f4f",
#                                                 "transportMode": "AUTO",
#                                                 "attributes": 128,
#                                                 "time": 4472,
#                                                 "iconUrl": "http://content.mqcdn.com/mqsite/turnsigns/rs_straight_sm.gif",
#                                                 "direction": 3
#                                         },
#                                         {
#                                                 "distance": 105.129,
#                                                 "streets": [
#                                                         "5"
#                                                 ],
#                                                 "narrative": "Stay straight to go onto 5.",
#                                                 "turnType": 0,
#                                                 "startPoint": {
#                                                         "lng": 26.070959,
#                                                         "lat": 61.283943
#                                                 },
#                                                 "index": 6,
#                                                 "formattedTime": "01:52:53",
#                                                 "directionName": "Northeast",
#                                                 "maneuverNotes": [],
#                                                 "linkIds": [],
#                                                 "signs": [],
#                                                 "mapUrl": "http://www.mapquestapi.com/staticmap/v5/map?key=th0o4YURLPy443wAxKekVk1OzaNOkJqm&size=225,160&locations=61.28394317626953,26.070959091186523|marker-7||62.302154541015625,27.86151695251465|marker-8||&center=61.79304885864258,26.966238021850586&defaultMarker=none&zoom=3&rand=-2074703914&session=604a3feb-03e4-4ee4-02b4-3580-126314f82f4f",
#                                                 "transportMode": "AUTO",
#                                                 "attributes": 128,
#                                                 "time": 6773,
#                                                 "iconUrl": "http://content.mqcdn.com/mqsite/turnsigns/rs_straight_sm.gif",
#                                                 "direction": 3
#                                         },
#                                         {
#                                                 "distance": 0.216,
#                                                 "streets": [],
#                                                 "narrative": "Take EXIT 46.",
#                                                 "turnType": 14,
#                                                 "startPoint": {
#                                                         "lng": 27.861517,
#                                                         "lat": 62.302155
#                                                 },
#                                                 "index": 7,
#                                                 "formattedTime": "00:00:28",
#                                                 "directionName": "North",
#                                                 "maneuverNotes": [],
#                                                 "linkIds": [],
#                                                 "signs": [
#                                                         {
#                                                                 "extraText": "",
#                                                                 "text": "46",
#                                                                 "type": 1001,
#                                                                 "url": "http://icons.mqcdn.com/icons/rs1001.png?n=46&d=RIGHT",
#                                                                 "direction": 0
#                                                         }
#                                                 ],
#                                                 "mapUrl": "http://www.mapquestapi.com/staticmap/v5/map?key=th0o4YURLPy443wAxKekVk1OzaNOkJqm&size=225,160&locations=62.302154541015625,27.86151695251465|marker-8||62.30525207519531,27.861492156982422|marker-9||&center=62.30370330810547,27.861504554748535&defaultMarker=none&zoom=11&rand=-2074703914&session=604a3feb-03e4-4ee4-02b4-3580-126314f82f4f",
#                                                 "transportMode": "AUTO",
#                                                 "attributes": 0,
#                                                 "time": 28,
#                                                 "iconUrl": "http://content.mqcdn.com/mqsite/turnsigns/rs_gr_exitright_sm.gif",
#                                                 "direction": 1
#                                         },
#                                         {
#                                                 "distance": 58.882,
#                                                 "streets": [
#                                                         "23"
#                                                 ],
#                                                 "narrative": "Turn right onto 23.",
#                                                 "turnType": 2,
#                                                 "startPoint": {
#                                                         "lng": 27.861492,
#                                                         "lat": 62.305252
#                                                 },
#                                                 "index": 8,
#                                                 "formattedTime": "01:07:42",
#                                                 "directionName": "Northeast",
#                                                 "maneuverNotes": [],
#                                                 "linkIds": [],
#                                                 "signs": [],
#                                                 "mapUrl": "http://www.mapquestapi.com/staticmap/v5/map?key=th0o4YURLPy443wAxKekVk1OzaNOkJqm&size=225,160&locations=62.30525207519531,27.861492156982422|marker-9||62.63448715209961,29.309091567993164|marker-10||&center=62.46986961364746,28.585291862487793&defaultMarker=none&zoom=4&rand=-2074703914&session=604a3feb-03e4-4ee4-02b4-3580-126314f82f4f",
#                                                 "transportMode": "AUTO",
#                                                 "attributes": 128,
#                                                 "time": 4062,
#                                                 "iconUrl": "http://content.mqcdn.com/mqsite/turnsigns/rs_right_sm.gif",
#                                                 "direction": 3
#                                         },
#                                         {
#                                                 "distance": 14.569,
#                                                 "streets": [
#                                                         "9",
#                                                         "23",
#                                                         "Kuopiontie"
#                                                 ],
#                                                 "narrative": "Turn right onto 9/23/Kuopiontie.",
#                                                 "turnType": 2,
#                                                 "startPoint": {
#                                                         "lng": 29.309092,
#                                                         "lat": 62.634487
#                                                 },
#                                                 "index": 9,
#                                                 "formattedTime": "00:14:35",
#                                                 "directionName": "East",
#                                                 "maneuverNotes": [],
#                                                 "linkIds": [],
#                                                 "signs": [],
#                                                 "mapUrl": "http://www.mapquestapi.com/staticmap/v5/map?key=th0o4YURLPy443wAxKekVk1OzaNOkJqm&size=225,160&locations=62.63448715209961,29.309091567993164|marker-10||62.61754608154297,29.7302188873291|marker-11||&center=62.62601661682129,29.519655227661133&defaultMarker=none&zoom=6&rand=-2074703914&session=604a3feb-03e4-4ee4-02b4-3580-126314f82f4f",
#                                                 "transportMode": "AUTO",
#                                                 "attributes": 128,
#                                                 "time": 875,
#                                                 "iconUrl": "http://content.mqcdn.com/mqsite/turnsigns/rs_right_sm.gif",
#                                                 "direction": 8
#                                         },
#                                         {
#                                                 "distance": 0.224,
#                                                 "streets": [],
#                                                 "narrative": "Take EXIT 24 toward Joensuu/Linnunlahti.",
#                                                 "turnType": 14,
#                                                 "startPoint": {
#                                                         "lng": 29.730219,
#                                                         "lat": 62.617546
#                                                 },
#                                                 "index": 10,
#                                                 "formattedTime": "00:00:22",
#                                                 "directionName": "Southeast",
#                                                 "maneuverNotes": [],
#                                                 "linkIds": [],
#                                                 "signs": [
#                                                         {
#                                                                 "extraText": "",
#                                                                 "text": "24",
#                                                                 "type": 1001,
#                                                                 "url": "http://icons.mqcdn.com/icons/rs1001.png?n=24&d=RIGHT",
#                                                                 "direction": 0
#                                                         }
#                                                 ],
#                                                 "mapUrl": "http://www.mapquestapi.com/staticmap/v5/map?key=th0o4YURLPy443wAxKekVk1OzaNOkJqm&size=225,160&locations=62.61754608154297,29.7302188873291|marker-11||62.61528778076172,29.734939575195312|marker-12||&center=62.616416931152344,29.732579231262207&defaultMarker=none&zoom=12&rand=-2074703914&session=604a3feb-03e4-4ee4-02b4-3580-126314f82f4f",
#                                                 "transportMode": "AUTO",
#                                                 "attributes": 0,
#                                                 "time": 22,
#                                                 "iconUrl": "http://content.mqcdn.com/mqsite/turnsigns/rs_gr_exitright_sm.gif",
#                                                 "direction": 5
#                                         },
#                                         {
#                                                 "distance": 1.224,
#                                                 "streets": [
#                                                         "Siltakatu"
#                                                 ],
#                                                 "narrative": "Merge onto Siltakatu.",
#                                                 "turnType": 10,
#                                                 "startPoint": {
#                                                         "lng": 29.73494,
#                                                         "lat": 62.615288
#                                                 },
#                                                 "index": 11,
#                                                 "formattedTime": "00:02:30",
#                                                 "directionName": "Southeast",
#                                                 "maneuverNotes": [],
#                                                 "linkIds": [],
#                                                 "signs": [],
#                                                 "mapUrl": "http://www.mapquestapi.com/staticmap/v5/map?key=th0o4YURLPy443wAxKekVk1OzaNOkJqm&size=225,160&locations=62.61528778076172,29.734939575195312|marker-12||62.60223388671875,29.757543563842773|marker-13||&center=62.608760833740234,29.746241569519043&defaultMarker=none&zoom=9&rand=-2074703914&session=604a3feb-03e4-4ee4-02b4-3580-126314f82f4f",
#                                                 "transportMode": "AUTO",
#                                                 "attributes": 0,
#                                                 "time": 150,
#                                                 "iconUrl": "http://content.mqcdn.com/mqsite/turnsigns/rs_merge_right_sm.gif",
#                                                 "direction": 5
#                                         },
#                                         {
#                                                 "distance": 0.094,
#                                                 "streets": [
#                                                         "Koulukatu"
#                                                 ],
#                                                 "narrative": "Turn right onto Koulukatu.",
#                                                 "turnType": 2,
#                                                 "startPoint": {
#                                                         "lng": 29.757544,
#                                                         "lat": 62.602234
#                                                 },
#                                                 "index": 12,
#                                                 "formattedTime": "00:00:25",
#                                                 "directionName": "Southwest",
#                                                 "maneuverNotes": [],
#                                                 "linkIds": [],
#                                                 "signs": [],
#                                                 "mapUrl": "http://www.mapquestapi.com/staticmap/v5/map?key=th0o4YURLPy443wAxKekVk1OzaNOkJqm&size=225,160&locations=62.60223388671875,29.757543563842773|marker-13||62.60099411010742,29.75636100769043|marker-14||&center=62.601613998413086,29.7569522857666&defaultMarker=none&zoom=13&rand=-2074703914&session=604a3feb-03e4-4ee4-02b4-3580-126314f82f4f",
#                                                 "transportMode": "AUTO",
#                                                 "attributes": 0,
#                                                 "time": 25,
#                                                 "iconUrl": "http://content.mqcdn.com/mqsite/turnsigns/rs_right_sm.gif",
#                                                 "direction": 6
#                                         },
#                                         {
#                                                 "distance": 0.272,
#                                                 "streets": [
#                                                         "Koskikatu"
#                                                 ],
#                                                 "narrative": "Turn left onto Koskikatu.",
#                                                 "turnType": 6,
#                                                 "startPoint": {
#                                                         "lng": 29.756361,
#                                                         "lat": 62.600994
#                                                 },
#                                                 "index": 13,
#                                                 "formattedTime": "00:01:09",
#                                                 "directionName": "East",
#                                                 "maneuverNotes": [],
#                                                 "linkIds": [],
#                                                 "signs": [],
#                                                 "mapUrl": "http://www.mapquestapi.com/staticmap/v5/map?key=th0o4YURLPy443wAxKekVk1OzaNOkJqm&size=225,160&locations=62.60099411010742,29.75636100769043|marker-14||62.599449157714844,29.764211654663086|marker-15||&center=62.60022163391113,29.760286331176758&defaultMarker=none&zoom=11&rand=-2074703914&session=604a3feb-03e4-4ee4-02b4-3580-126314f82f4f",
#                                                 "transportMode": "AUTO",
#                                                 "attributes": 0,
#                                                 "time": 69,
#                                                 "iconUrl": "http://content.mqcdn.com/mqsite/turnsigns/rs_left_sm.gif",
#                                                 "direction": 8
#                                         },
#                                         {
#                                                 "distance": 0.093,
#                                                 "streets": [
#                                                         "Rantakatu"
#                                                 ],
#                                                 "narrative": "Turn left onto Rantakatu.",
#                                                 "turnType": 6,
#                                                 "startPoint": {
#                                                         "lng": 29.764212,
#                                                         "lat": 62.599449
#                                                 },
#                                                 "index": 14,
#                                                 "formattedTime": "00:00:22",
#                                                 "directionName": "Northeast",
#                                                 "maneuverNotes": [],
#                                                 "linkIds": [],
#                                                 "signs": [],
#                                                 "mapUrl": "http://www.mapquestapi.com/staticmap/v5/map?key=th0o4YURLPy443wAxKekVk1OzaNOkJqm&size=225,160&locations=62.599449157714844,29.764211654663086|marker-15||62.60068893432617,29.765363693237305|marker-16||&center=62.60006904602051,29.764787673950195&defaultMarker=none&zoom=13&rand=-2074703914&session=604a3feb-03e4-4ee4-02b4-3580-126314f82f4f",
#                                                 "transportMode": "AUTO",
#                                                 "attributes": 0,
#                                                 "time": 22,
#                                                 "iconUrl": "http://content.mqcdn.com/mqsite/turnsigns/rs_left_sm.gif",
#                                                 "direction": 3
#                                         },
#                                         {
#                                                 "distance": 0.048,
#                                                 "streets": [
#                                                         "Siltakatu"
#                                                 ],
#                                                 "narrative": "Turn right onto Siltakatu.",
#                                                 "turnType": 2,
#                                                 "startPoint": {
#                                                         "lng": 29.765364,
#                                                         "lat": 62.600689
#                                                 },
#                                                 "index": 15,
#                                                 "formattedTime": "00:00:08",
#                                                 "directionName": "Southeast",
#                                                 "maneuverNotes": [],
#                                                 "linkIds": [],
#                                                 "signs": [],
#                                                 "mapUrl": "http://www.mapquestapi.com/staticmap/v5/map?key=th0o4YURLPy443wAxKekVk1OzaNOkJqm&size=225,160&locations=62.60068893432617,29.765363693237305|marker-16||62.60041427612305,29.766738891601562|marker-17||&center=62.60055160522461,29.766051292419434&defaultMarker=none&zoom=15&rand=-2074703914&session=604a3feb-03e4-4ee4-02b4-3580-126314f82f4f",
#                                                 "transportMode": "AUTO",
#                                                 "attributes": 0,
#                                                 "time": 8,
#                                                 "iconUrl": "http://content.mqcdn.com/mqsite/turnsigns/rs_right_sm.gif",
#                                                 "direction": 5
#                                         },
#                                         {
#                                                 "distance": 0,
#                                                 "streets": [],
#                                                 "narrative": "Welcome to GIOENSOU, IT\u00c4-SUOMI.",
#                                                 "turnType": -1,
#                                                 "startPoint": {
#                                                         "lng": 29.766739,
#                                                         "lat": 62.600414
#                                                 },
#                                                 "index": 16,
#                                                 "formattedTime": "00:00:00",
#                                                 "directionName": "",
#                                                 "maneuverNotes": [],
#                                                 "linkIds": [],
#                                                 "signs": [],
#                                                 "transportMode": "AUTO",
#                                                 "attributes": 0,
#                                                 "time": 0,
#                                                 "iconUrl": "http://content.mqcdn.com/mqsite/turnsigns/icon-dirs-end_sm.gif",
#                                                 "direction": 0
#                                         }
#                                 ],
#                                 "hasFerry": false
#                         }
#                 ],
#                 "options": {
#                         "arteryWeights": [],
#                         "cyclingRoadFactor": 1,
#                         "timeType": 0,
#                         "useTraffic": false,
#                         "returnLinkDirections": false,
#                         "countryBoundaryDisplay": true,
#                         "enhancedNarrative": false,
#                         "locale": "en_US",
#                         "tryAvoidLinkIds": [],
#                         "drivingStyle": 2,
#                         "doReverseGeocode": true,
#                         "generalize": -1,
#                         "mustAvoidLinkIds": [],
#                         "sideOfStreetDisplay": true,
#                         "routeType": "FASTEST",
#                         "avoidTimedConditions": false,
#                         "routeNumber": 0,
#                         "shapeFormat": "raw",
#                         "maxWalkingDistance": -1,
#                         "destinationManeuverDisplay": true,
#                         "transferPenalty": -1,
#                         "narrativeType": "text",
#                         "walkingSpeed": -1,
#                         "urbanAvoidFactor": -1,
#                         "stateBoundaryDisplay": true,
#                         "unit": "M",
#                         "highwayEfficiency": 22,
#                         "maxLinkId": 0,
#                         "maneuverPenalty": -1,
#                         "avoidTripIds": [],
#                         "filterZoneFactor": -1,
#                         "manmaps": "true"
#                 },
#                 "locations": [
#                         {
#                                 "dragPoint": false,
#                                 "displayLatLng": {
#                                         "lng": 24.943508,
#                                         "lat": 60.16663
#                                 },
#                                 "adminArea4": "",
#                                 "adminArea5": "Helsinki",
#                                 "postalCode": "",
#                                 "adminArea1": "FI",
#                                 "adminArea3": "SOUTHERN FINLAND",
#                                 "type": "s",
#                                 "sideOfStreet": "N",
#                                 "geocodeQualityCode": "A5XAX",
#                                 "adminArea4Type": "County",
#                                 "linkId": 92992710,
#                                 "street": "",
#                                 "adminArea5Type": "City",
#                                 "geocodeQuality": "CITY",
#                                 "adminArea1Type": "Country",
#                                 "adminArea3Type": "State",
#                                 "latLng": {
#                                         "lng": 24.943508,
#                                         "lat": 60.166628
#                                 }
#                         },
#                         {
#                                 "dragPoint": false,
#                                 "displayLatLng": {
#                                         "lng": 29.766659,
#                                         "lat": 62.600014
#                                 },
#                                 "adminArea4": "",
#                                 "adminArea5": "Gioensou",
#                                 "postalCode": "",
#                                 "adminArea1": "FI",
#                                 "adminArea3": "IT\u00c4-SUOMI",
#                                 "type": "s",
#                                 "sideOfStreet": "N",
#                                 "geocodeQualityCode": "A5XAX",
#                                 "adminArea4Type": "County",
#                                 "linkId": 12945495,
#                                 "street": "",
#                                 "adminArea5Type": "City",
#                                 "geocodeQuality": "CITY",
#                                 "adminArea1Type": "Country",
#                                 "adminArea3Type": "State",
#                                 "latLng": {
#                                         "lng": 29.766659,
#                                         "lat": 62.600015
#                                 }
#                         }
#                 ],
#                 "time": 17071,
#                 "hasUnpaved": false,
#                 "locationSequence": [
#                         0,
#                         1
#                 ],
#                 "hasFerry": false
#         },
#         "info": {
#                 "statuscode": 0,
#                 "copyright": {
#                         "imageAltText": "\u00a9 2021 MapQuest, Inc.",
#                         "imageUrl": "http://api.mqcdn.com/res/mqlogo.gif",
#                         "text": "\u00a9 2021 MapQuest, Inc."
#                 },
#                 "messages": []
#         }
# }

# %%
print('STEP 7: Calculating duration and distance')
if json_status == 0:         
    print("API Status: " + str(json_status) + " = A successful route call.\n")         
    print("=============================================")         
    print("Directions from  " + (orig) + " to " + (dest))         
    print("Trip Duration:   " + (json_data["route"]["formattedTime"]))         
    print("Distance (Km):   " + str("{:.2f}".format(json_data["route"]["distance"]*1.61,3)))
    print("Fuel Used (l):   " + str("{:.2f}".format(json_data["route"]["fuelUsed"]*3.78,3)))
    print("=============================================") 
else:
    print('Unfortunately, JSON request not succesfull')
    print('JSON status: ' +  str(json_status))
# Out:
# STEP 7: Calculating duration and distance
# API Status: 0 = A successful route call.
#
# =============================================
# Directions from  Helsinki to Joensuu
# Trip Duration:   04:44:31
# Distance (Km):   437.32
# Fuel Used (l):   47.17
# =============================================

# %%
if json_status == 0: 
    print('STEP 8: List of maneuvers from start to finish ...')
    print("=============================================================") 
    for each in json_data["route"]["legs"][0]["maneuvers"]:
        print((each["narrative"]) + " (" + str("{:.2f}".format((each["distance"])*1.61) + " km)"))
        print("=============================================================\n") 
elif json_status == 402:         
    print("**********************************************")         
    print("Status Code: " + str(json_status) + "; Invalid user inputs for one or both locations.")         
    print("**********************************************\n")     
else:         
    print("************************************************************************")         
    print("For Status Code: " + str(json_status) + "; Refer to:")         
    print("https://developer.mapquest.com/documentation/directions-api/status-codes")         
    print("************************************************************************\n")
# Out:
# STEP 8: List of maneuvers from start to finish ...
# =============================================================
# Start out going northeast on Bulevardi toward Erottajankatu. (0.01 km)
# =============================================================
#
# Turn left onto Mannerheimintie/E12. (1.80 km)
# =============================================================
#
# Turn right onto Helsinginkatu. (1.03 km)
# =============================================================
#
# Turn slight left onto Sturenkatu. (1.78 km)
# =============================================================
#
# Turn slight left onto Hämeentie. (0.68 km)
# =============================================================
#
# Stay straight to go onto Kustaa Vaasan tie/E75. Continue to follow E75. (141.02 km)
# =============================================================
#
# Stay straight to go onto 5. (169.26 km)
# =============================================================
#
# Take EXIT 46. (0.35 km)
# =============================================================
#
# Turn right onto 23. (94.80 km)
# =============================================================
#
# Turn right onto 9/23/Kuopiontie. (23.46 km)
# =============================================================
#
# Take EXIT 24 toward Joensuu/Linnunlahti. (0.36 km)
# =============================================================
#
# Merge onto Siltakatu. (1.97 km)
# =============================================================
#
# Turn right onto Koulukatu. (0.15 km)
# =============================================================
#
# Turn left onto Koskikatu. (0.44 km)
# =============================================================
#
# Turn left onto Rantakatu. (0.15 km)
# =============================================================
#
# Turn right onto Siltakatu. (0.08 km)
# =============================================================
#
# Welcome to GIOENSOU, ITÄ-SUOMI. (0.00 km)
# =============================================================
